# %% [markdown]
# # Exploratory Data Analysis (EDA)
# This notebook explores the student placement dataset to understand feature distributions, missing values, and target class balance .

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
df = pd.read_csv("../Data/Raw/placement_data.csv") #Loading dataset CSV file into pandas dataframe
df.head() #Inspecting few sample rows
# Out:
#    StudentID  CGPA  Internships  Projects  Workshops/Certifications  \
# 0          1   7.5            1         1                         1
# 1          2   8.9            0         3                         2
# 2          3   7.3            1         2                         2
# 3          4   7.5            1         1                         2
# 4          5   8.3            1         2                         2
#
#    AptitudeTestScore  SoftSkillsRating ExtracurricularActivities  \
# 0                 65               4.4                        No
# 1                 90               4.0                       Yes
# 2                 82               4.8                       Yes
# 3                 85               4.4                       Yes
# 4                 86               4.5                       Yes
#
#   PlacementTraining  SSC_Marks  HSC_Marks PlacementStatus
# 0                No         61         79       NotPlaced
# ...

# %%
# %pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df.shape #size
# Out:
# (10000, 12)

# %%
df['PlacementStatus'].value_counts() #count for both status
# Out:
# PlacementStatus
# NotPlaced    5803
# Placed       4197
# Name: count, dtype: int64

# %%
df.info()   #Quick summary of dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   StudentID                  10000 non-null  int64
#  1   CGPA                       10000 non-null  float64
#  2   Internships                10000 non-null  int64
#  3   Projects                   10000 non-null  int64
#  4   Workshops/Certifications   10000 non-null  int64
#  5   AptitudeTestScore          10000 non-null  int64
#  6   SoftSkillsRating           10000 non-null  float64
#  7   ExtracurricularActivities  10000 non-null  object
#  8   PlacementTraining          10000 non-null  object
#  9   SSC_Marks                  10000 non-null  int64
#  10  HSC_Marks                  10000 non-null  int64
#  11  PlacementStatus            10000 non-null  object
# dtypes: float64(2), int64(7), object(3)
# memory usage: 937.6+ KB

# %%
df.describe()   #Statistical Summary
# Out:
#          StudentID          CGPA   Internships      Projects  \
# count  10000.00000  10000.000000  10000.000000  10000.000000
# mean    5000.50000      7.698010      1.049200      2.026600
# std     2886.89568      0.640131      0.665901      0.867968
# min        1.00000      6.500000      0.000000      0.000000
# 25%     2500.75000      7.400000      1.000000      1.000000
# 50%     5000.50000      7.700000      1.000000      2.000000
# 75%     7500.25000      8.200000      1.000000      3.000000
# max    10000.00000      9.100000      2.000000      3.000000
#
#        Workshops/Certifications  AptitudeTestScore  SoftSkillsRating  \
# count              10000.000000       10000.000000      10000.000000
# mean                   1.013200          79.449900          4.323960
# std                    0.904272           8.159997          0.411622
# min                    0.000000          60.000000          3.000000
# ...

# %%
df['ExtracurricularActivities'].value_counts()
df['PlacementTraining'].value_counts()  #count for particular columns
# Out:
# PlacementTraining
# Yes    7318
# No     2682
# Name: count, dtype: int64

# %%
df_model=df.copy()   #Creating copy of dataframe
df_model['PlacementStatus']=df_model['PlacementStatus'].map({
    'Placed':1 ,
    'NotPlaced':0         #Converting Target status to numeric
})

df_model=df_model.drop(columns=['StudentID'])  #Dropping The StudentID column
df_model.head()
# Out:
#    CGPA  Internships  Projects  Workshops/Certifications  AptitudeTestScore  \
# 0   7.5            1         1                         1                 65
# 1   8.9            0         3                         2                 90
# 2   7.3            1         2                         2                 82
# 3   7.5            1         1                         2                 85
# 4   8.3            1         2                         2                 86
#
#    SoftSkillsRating ExtracurricularActivities PlacementTraining  SSC_Marks  \
# 0               4.4                        No                No         61
# 1               4.0                       Yes               Yes         78
# 2               4.8                       Yes                No         79
# 3               4.4                       Yes               Yes         81
# 4               4.5                       Yes               Yes         74
#
#    HSC_Marks  PlacementStatus
# ...

# %%
corr=df_model.corr(numeric_only=True) #Computing correlation Matrix
plt.figure(figsize=(10,6))
sns.heatmap(corr,annot=True,cmap='coolwarm')   #Heatmap Visualisation
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# ## EDA Summary
#
# - The dataset shows moderate variation in academic and skill-based features.
# - No severe missing data issues were observed.
# - The target variable is slightly imbalanced but manageable.
# - Certain features such as Aptitude Score and Training appear to have strong correlation with placement.

# %%
X = df.drop(columns=['StudentID','PlacementStatus']) #Dropping StudentId and Target value because they had no predictive value

y = df['PlacementStatus']  #Y contain Output label

# %%
y = y.map({'Placed' : 1 , 'NotPlaced' : 0}) #converting categorical labels in to numeric values

# %%
# Convert Yes/No columns into numeric form

X['ExtracurricularActivities'] = X['ExtracurricularActivities'].map({'Yes':1, 'No':0})
X['PlacementTraining'] = X['PlacementTraining'].map({'Yes':1, 'No':0})

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,    # 20% data for testing
    random_state=42,  # Same Split
    stratify=y        # Class balance
)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

model.fit(X_train , y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix , classification_report

print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[966 195]
#  [188 651]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.83      0.83      1161
#            1       0.77      0.78      0.77       839
#
#     accuracy                           0.81      2000
#    macro avg       0.80      0.80      0.80      2000
# weighted avg       0.81      0.81      0.81      2000

# %% [markdown]
# The model achieved 81% accuracy with balanced precision and recall across both classes. Performance is slightly stronger for the majority class, but F1 scores indicate stable classification performance without severe bias.

# %%
from sklearn.metrics import roc_curve , roc_auc_score
import matplotlib.pyplot as plt

# Predict the Probabilities 
y_prob = model.predict_proba(X_test)[:,1] # predicting probability of class 1

fpr ,tpr ,thresholds =  roc_curve(y_test,y_prob) # Roc curve

auc = roc_auc_score(y_test,y_prob) # auc score

# Plot Roc curve
plt.plot(fpr,tpr,label = "Auc =" +str(round(auc,3)))

plt.xlabel("False Positive Rate") # 1 - Specificity
plt.ylabel("True positive Rate") # Sensitiviy or Recall
plt.title("Roc Curve")
plt.plot([0,1],[0,1] ,'--')
plt.legend()
plt.show()

# %% [markdown]
# The ROC curve analysis produced an AUC score of 0.884, indicating strong discriminative capability of the model. This suggests that the logistic regression model is effective in distinguishing between students who are likely to be placed and those who are not

# %%
feature_importance = pd.Series(model.coef_[0],index = X.columns)
feature_importance.sort_values(ascending=False)
# Out:
# AptitudeTestScore            0.610808
# PlacementTraining            0.391990
# ExtracurricularActivities    0.360371
# SSC_Marks                    0.282628
# SoftSkillsRating             0.263450
# CGPA                         0.257470
# Projects                     0.254356
# HSC_Marks                    0.221181
# Workshops/Certifications     0.095102
# Internships                 -0.010932
# dtype: float64

# %% [markdown]
# Feature coefficient analysis shows that Aptitude Test Score has the strongest influence on placement probability, followed by placement training and extracurricular activities. Academic metrics such as SSC marks, CGPA, and soft skills also contribute positively. Internship count had negligible impact in this dataset.

# %% [markdown]
# ADVANCE PARTS TO MAKE STRONGER PROJECT

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score , roc_auc_score

tree = DecisionTreeClassifier(random_state=42) # Creating Decision tree model  
tree.fit(X_train , y_train)
y_pred_tree = tree.predict(X_test)
y_prob_tree = tree.predict_proba(X_test)[:,1]

acc_tree = accuracy_score(y_test ,y_pred_tree)
auc_tree = roc_auc_score(y_test , y_prob_tree)

print("Decision Tree Accuracy:", acc_tree)
print("Decision Tree AUC:", auc_tree)
# Out:
# Decision Tree Accuracy: 0.7215
# Decision Tree AUC: 0.7144199803096053

# %% [markdown]
# The Decision Tree model achieved an accuracy of 72.15% and an AUC score of 0.71.
# This performance is lower than the Logistic Regression model (accuracy ≈ 81%, AUC ≈ 0.884).
# This suggests that the relationship between the features and the target variable is relatively linear,
# making Logistic Regression a better choice for this dataset.

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100 , random_state=42)
rf.fit(X_train , y_train)
y_pred_rf = rf.predict(X_test)
y_prob_rf = rf.predict_proba(X_test)[:,1]

acc_rf = accuracy_score(y_test , y_pred_rf)
auc_rf = roc_auc_score(y_test , y_prob_rf)

print("Random Forest Accuracy :",acc_rf)
print("Random Forest Auc :",auc_rf)
# Out:
# Random Forest Accuracy : 0.7875
# Random Forest Auc : 0.8667869854498453

# %%
rf_importance = pd.Series(rf.feature_importances_ , index = X.columns)
rf_importance.sort_values(ascending=False)
# Out:
# HSC_Marks                    0.202770
# AptitudeTestScore            0.169404
# SSC_Marks                    0.135595
# CGPA                         0.123857
# SoftSkillsRating             0.090761
# Projects                     0.086133
# ExtracurricularActivities    0.081466
# Workshops/Certifications     0.052555
# Internships                  0.034366
# PlacementTraining            0.023093
# dtype: float64

# %%
rf_importance.sort_values().plot(kind = 'barh' ,figsize=(8,5))
plt.title("Random Forest")
plt.xlabel("Important Score")
plt.show()

# %%
results = pd.DataFrame({
    "Model":["Logistic Regression","Decision Tree","Random Forest"],
    "Accuracy" :[0.81,0.72,0.79],
    "Roc-Auc" :[0.84,0.71,0.867]
})
results
# Out:
#                  Model  Accuracy  Roc-Auc
# 0  Logistic Regression      0.81    0.840
# 1        Decision Tree      0.72    0.710
# 2        Random Forest      0.79    0.867

# %% [markdown]
# A simpler model can outperform more complex models when the underlying relationship between features and the target variable is approximately linear
#
# Three models were evaluated for predicting student placement: Logistic Regression, Decision Tree, and Random Forest. Logistic Regression achieved the best performance with an AUC score of 0.884 and an accuracy of approximately 81%. Decision Trees showed lower performance due to overfitting, while Random Forest improved upon the Decision Tree but still performed slightly worse than Logistic Regression. This suggests that the relationship between features and placement outcome is largely linear

# %% [markdown]
# ## Cross Validation

# %%
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression

model_cv = LogisticRegression(max_iter=1000) # Increasing max iterations for convergence

scores = cross_val_score(model_cv,X,y,cv=5) # 5Fold Cross Validation
print("Cross-Validation Scores:", scores)
print("Average Cross-Validation Score:", scores.mean())
# Out:
# Cross-Validation Scores: [0.7935 0.796  0.812  0.7945 0.804 ]
# Average Cross-Validation Score: 0.8000000000000002

# %% [markdown]
# Cross-validation results show that the model achieves an average accuracy of approximately 80% across 5 folds. The low variation in scores indicates that the model is stable and generalizes well to unseen data. This confirms that the model is not overfitting and provides reliable performance.

# %% [markdown]
# ## HyperParameter tuning GridsearchCV

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression 

param_grid = {
    'C':[0.01,0.1,1,10], #  Regularization strength
}

model = LogisticRegression(max_iter=1000) # Increasing max iterations for convergence
grid = GridSearchCV(model, param_grid, cv=5) # Grid Search with 5 Fold Cross Validation

grid.fit(X_train,y_train)
print("Best Hyperparameters:", grid.best_params_)
print("Best Cross-Validation Score:", grid.best_score_)
# Out:
# Best Hyperparameters: {'C': 1}
# Best Cross-Validation Score: 0.79675

# %% [markdown]
# GridSearchCV was used to tune the regularization parameter C in Logistic Regression.
# The best value of C was found to be 1, with a cross-validation score of approximately 0.797.
# The performance is very close to the default model, indicating that the model is already well-optimized and stable.

# %% [markdown]
# ## Default Model

# %%
model_default = LogisticRegression(max_iter=1000) # Default Hyperparameters
model_default.fit(X_train , y_train)
y_pred_default = model_default.predict(X_test)

# %% [markdown]
# ## Tuned Model

# %%
best_model = grid.best_estimator_ # Best Model from Grid Search
y_pred_best = best_model.predict(X_test)

# %% [markdown]
# ## Balanced Model

# %%
model_balanced = LogisticRegression(max_iter=1000, class_weight='balanced') # Handling Class Imbalance
model_balanced.fit(X_train , y_train)
y_pred_balanced = model_balanced.predict(X_test)

# %% [markdown]
# ## Evaluation of all Models

# %%
from sklearn.metrics import accuracy_score, roc_auc_score

acc_default = accuracy_score(y_test , y_pred_default)
auc_default = roc_auc_score(y_test , model_default.predict_proba(X_test)[:,1])

acc_best = accuracy_score(y_test , y_pred_best)
auc_best = roc_auc_score(y_test , best_model.predict_proba(X_test)[:,1])

acc_balanced = accuracy_score(y_test , y_pred_balanced)
auc_balanced = roc_auc_score(y_test , model_balanced.predict_proba(X_test)[:,1])

# %%
import pandas as pd
final_results = pd.DataFrame({
    "Model":["Default Logistic Regression","Best Logistic Regression","Balanced Logistic Regression"],
    "Accuracy":[acc_default, acc_best, acc_balanced],
    "Roc-Auc":[auc_default, auc_best, auc_balanced]
})
final_results
# Out:
#                           Model  Accuracy   Roc-Auc
# 0   Default Logistic Regression    0.8085  0.883720
# 1      Best Logistic Regression    0.8085  0.883720
# 2  Balanced Logistic Regression    0.7995  0.883749

# %% [markdown]
# ## Final Model Comparison
#
# The default and tuned Logistic Regression models achieved identical performance, indicating that the default hyperparameters were already optimal.
#
# The balanced model showed a slight decrease in accuracy but maintained a similar ROC-AUC score. This indicates that while overall accuracy decreased slightly, the model's ability to distinguish between classes remained strong.
#
# The balanced model is particularly useful in this context as it improves the detection of the minority class (placed students), reducing false negatives and making the predictions more fair and meaningful.

# %% [markdown]
# ## Increasing recall for placed students

# %%
y_prob = model_default.predict_proba(X_test)[:,1]
thresholds =  0.4 # Different thresholds to evaluate
y_pred_threshold = (y_prob >= thresholds).astype(int) # Predicting based on threshold

from sklearn.metrics import confusion_matrix , classification_report
print("New Classification Report:\n")
print(classification_report(y_test,y_pred_threshold))

print("\nNew confusion Matrix:\n")
print(confusion_matrix(y_test,y_pred_threshold))
# Out:
# New Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.86      0.77      0.81      1161
#            1       0.72      0.83      0.77       839
#
#     accuracy                           0.79      2000
#    macro avg       0.79      0.80      0.79      2000
# weighted avg       0.80      0.79      0.80      2000
#
#
# New confusion Matrix:
#
# [[893 268]
#  [143 696]]

# %% [markdown]
# We traded accuracy for recall

# %% [markdown]
# ## Threshold Tuning Analysis
#
# By lowering the classification threshold from 0.5 to 0.4, the model improves recall for the placed class from 0.78 to 0.83. This reduces false negatives from 188 to 143, meaning more students who are actually placed are correctly identified.
#
# Although the overall accuracy decreases slightly from 0.81 to 0.79, this tradeoff is acceptable because identifying potential placed students is more important than maximizing accuracy.
#
# This demonstrates how adjusting the decision threshold can significantly improve model performance for specific objectives.

# %% [markdown]
# ## Conclusion
#
#      This Project developed a machine learning system to predict student placement outcomes based on academic performance  , technical skills , and training factors .
#
#      Three Models were evaluated : Logistic Regression  , Decision Tree , Random Forest .
#
#      Logistic Regression achieved the best performance with an ROC-AUC score of 0.884 and an accuracy of approximately 81% .
#
#      The results suggest that aptitude test scores , placement training , extracurricular activities are the most influential factors affecting placement probability .
#
#      This indicates that the relationship between the features and the placement outcome is largely linear  , making  Logistic Regression an effective model for this dataset.

# %% [markdown]
# ## Limitations
#
#     - The dataset may not fully represent real-world placement  scenarios.
#
#     - Some important features such as interview performance ,  coding test results , and company performance are not included.
#
#     -The internship feature showed very low predictive importance , which indicate dataset bias.
#
#
# ## Future Work
#
#     - Collect real-world placement features with richer features.
#
#     - Apply advance models such as Gradient Boosting or XGBoost.
#
#     - Deploy the model as a web apllication for predicting placement probability.

# %%
import joblib

joblib.dump(model_default, "model.pkl")
# Out:
# ['model.pkl']

# %%
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']
